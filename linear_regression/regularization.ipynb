# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("08-Linear-Regression-Models/Advertising.csv")

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
X = df.drop('sales', axis=1)

# %%
y = df['sales']

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
poly_features = polynomial_converter.fit_transform(X)

# %%
poly_features.shape
# Out:
# (200, 19)

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(poly_features, y, test_size=0.30, random_state=101)

# %%
X_train.shape
# Out:
# (140, 19)

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()

# %%
scaler.fit(X_train)
# Out:
# StandardScaler()

# %%
X_train = scaler.transform(X_train)

# %%
X_test = scaler.transform(X_test)

# %%
X_train[0]
# Out:
# array([ 0.49300171, -0.33994238,  1.61586707,  0.28407363, -0.02568776,
#         1.49677566, -0.59023161,  0.41659155,  1.6137853 ,  0.08057172,
#        -0.05392229,  1.01524393, -0.36986163,  0.52457967,  1.48737034,
#        -0.66096022, -0.16360242,  0.54694754,  1.37075536])

# %%
poly_features[0]
# Out:
# array([2.30100000e+02, 3.78000000e+01, 6.92000000e+01, 5.29460100e+04,
#        8.69778000e+03, 1.59229200e+04, 1.42884000e+03, 2.61576000e+03,
#        4.78864000e+03, 1.21828769e+07, 2.00135918e+06, 3.66386389e+06,
#        3.28776084e+05, 6.01886376e+05, 1.10186606e+06, 5.40101520e+04,
#        9.88757280e+04, 1.81010592e+05, 3.31373888e+05])

# %%
from sklearn.linear_model import Ridge

# %%
ridge_model = Ridge(alpha=10)

# %%
ridge_model.fit(X_train, y_train)
# Out:
# Ridge(alpha=10)

# %%
test_predictions = ridge_model.predict(X_test)

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
MAE = mean_absolute_error(y_test, test_predictions)

# %%
RMSE = np.sqrt(mean_squared_error(y_test, test_predictions))

# %%
MAE
# Out:
# 0.5774404204714166

# %%
RMSE
# Out:
# np.float64(0.8946386461319648)

# %%
from sklearn.linear_model import RidgeCV

# %%
alphas = np.arange(0.03, 0.036, 0.002)

# %%
ridge_cv_model = RidgeCV(alphas=alphas, scoring='neg_mean_absolute_error')

# %%
ridge_cv_model.fit(X_train, y_train)
# Out:
# RidgeCV(alphas=array([0.03 , 0.032, 0.034]), scoring='neg_mean_absolute_error')

# %%
ridge_cv_model.alpha_
# Out:
# np.float64(0.034)

# %%
from sklearn.metrics import get_scorer_names

# %%
test_predictions = ridge_cv_model.predict(X_test)

# %%
MAE = mean_squared_error(y_test, test_predictions)

# %%
RMSE = np.sqrt(mean_squared_error(y_test, test_predictions))

# %%
MAE
# Out:
# 0.350096085544906

# %%
RMSE
# Out:
# np.float64(0.5916891798443723)

# %%
ridge_cv_model.coef_
# Out:
# array([ 6.35423607,  0.53275916,  0.34628204, -8.42699296,  4.93412287,
#        -1.51532945, -1.28550853,  0.6987823 ,  0.16719928,  3.85461056,
#        -1.50567833,  1.23998099,  0.53138815, -0.29765577,  0.09203623,
#         0.64047236, -0.27459808, -0.15328233, -0.17456777])

# %%
ridge_cv_model.best_score_
# Out:
# -0.3608256631824797

# %%
from sklearn.linear_model import LassoCV

# %%
lasso_cv_model = LassoCV(eps=0.001, alphas=100, max_iter=100000)

# %%
lasso_cv_model.fit(X_train, y_train)
# Out:
# LassoCV(alphas=100, max_iter=100000)

# %%
lasso_cv_model.alpha_
# Out:
# np.float64(0.004943070909225831)

# %%
test_predictions = lasso_cv_model.predict(X_test)

# %%
MAE = mean_squared_error(y_test, test_predictions)

# %%
RMSE = np.sqrt(mean_squared_error(y_test, test_predictions))

# %%
MAE
# Out:
# 0.367616757419907

# %%
RMSE
# Out:
# np.float64(0.6063140748984036)

# %%
lasso_cv_model.coef_
# Out:
# array([ 4.86023329,  0.12544598,  0.20746872, -4.99250395,  4.38026519,
#        -0.22977201, -0.        ,  0.07267717, -0.        ,  1.77780246,
#        -0.69614918, -0.        ,  0.12044132, -0.        , -0.        ,
#        -0.        ,  0.        ,  0.        , -0.        ])

# %%
from sklearn.linear_model import ElasticNetCV

# %%
elastic_model = ElasticNetCV(l1_ratio=[.1, .5, .7, .9, .99, 1], eps=0.001, n_alphas=100, max_iter=1000000)

# %%
elastic_model.fit(X_train, y_train)
# Out:
# C:\Users\Asus\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\linear_model\_coordinate_descent.py:1622: FutureWarning: 'n_alphas' was deprecated in 1.7 and will be removed in 1.9. 'alphas' now accepts an integer value which removes the need to pass 'n_alphas'. The default value of 'alphas' will change from None to 100 in 1.9. Pass an explicit value to 'alphas' and leave 'n_alphas' to its default value to silence this warning.
#   warnings.warn(
# ElasticNetCV(l1_ratio=[0.1, 0.5, 0.7, 0.9, 0.99, 1], max_iter=1000000,
#              n_alphas=100)

# %%
elastic_model.l1_ratio_
# Out:
# np.float64(1.0)

# %%
elastic_model.alpha_
# Out:
# np.float64(0.004943070909225831)

# %%
test_predictions = elastic_model.predict(X_test)

# %%
MSE = mean_squared_error(y_test, test_predictions)

# %%
RMSE = np.sqrt(mean_squared_error(y_test, test_predictions))

# %%
MSE
# Out:
# 0.367616757419907

# %%
RMSE
# Out:
# np.float64(0.6063140748984036)
