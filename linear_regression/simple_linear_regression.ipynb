# %%
import pandas as pd
import numpy as np 
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("08-Linear-Regression-Models/Advertising.csv")

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales
# 0  230.1   37.8       69.2   22.1
# 1   44.5   39.3       45.1   10.4
# 2   17.2   45.9       69.3    9.3
# 3  151.5   41.3       58.5   18.5
# 4  180.8   10.8       58.4   12.9

# %%
df['total_spend'] = df['TV'] + df['radio'] + df['newspaper']

# %%
df.head()
# Out:
#       TV  radio  newspaper  sales  total_sales  total_spend
# 0  230.1   37.8       69.2   22.1        337.1        337.1
# 1   44.5   39.3       45.1   10.4        128.9        128.9
# 2   17.2   45.9       69.3    9.3        132.4        132.4
# 3  151.5   41.3       58.5   18.5        251.3        251.3
# 4  180.8   10.8       58.4   12.9        250.0        250.0

# %%
sns.scatterplot(data=df, x="total_spend", y="sales")
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
sns.regplot(data=df, x="total_spend", y="sales")
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
X = df['total_spend']
y = df['sales']

# %%
np.polyfit(X, y, deg=1)
# Out:
# array([0.04868788, 4.24302822])

# %%
potential_spend = np.linspace(5,500,100)

# %%
predicted_sales = 0.04868788 * potential_spend + 4.24302822

# %%
plt.plot(potential_spend, predicted_sales, color='red')
sns.scatterplot(data=df, x="total_spend", y="sales")
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>

# %%
spend = 200
predicted_sale = 0.04868788 * spend + 4.24302822

# %%
predicted_sale
# Out:
# 13.98060422

# %%
np.polyfit(X,y,deg=4)
# Out:
# array([-1.32539028e-09,  1.46034814e-06, -5.23540362e-04,  1.18664227e-01,
#         1.51379069e+00])

# %%
pot_spend = np.linspace(5,500,100)

# %%
pred_sales = -1.32539028e-09 * pot_spend**4 + \
              1.46034814e-06 * pot_spend**3 + \
             -5.23540362e-04 * pot_spend**2 + \
              1.18664227e-01 * pot_spend    + \
              1.51379069e+00

# %%
plt.plot(pot_spend, pred_sales, color='red')
sns.scatterplot(data=df, x="total_spend", y="sales")
# Out:
# <Axes: xlabel='total_spend', ylabel='sales'>
